# %% [markdown]
# # Домашнее задание №2 «Проектное задание»
# *Выполнили: Новосерьянц Эдуард Отарикович, Ухов Игорь Викторович*

# %% [markdown]
# ## 1. Название задания

# %% [markdown]
#  #### «**Просачивание**» ####

# %% [markdown]
# ## 2. Реализация

# %% [markdown]
# ### 2.1 Псевдокод алгоритма

# %% [markdown]
# *вставьте сюда псевдокод вашего алгоритма в нотации, используемой на лекциях (пронумеруйте все строки, выделяйте ключевые слова, делайте отступы и т.д.)*

# %% [markdown]
# ### 2.2 Описание работы алгоритма

# %% [markdown]
# *опишите логику работы вашего алгоритма, ссылаясь на номера строк псевдокода*

# %% [markdown]
# ### 2.3 Оценка времени работы

# %% [markdown]
# ##### __Для QuickFind:__
# Удваивание размера массива увеличивает время выполнения примерно в 15 раз. Удваивание кол-ва экспериментов также увеличивает время в два раза.
#
# ##### __Для QuickUnion:__
# Удваивание размера массива увеличивает время выполнения примерно в 18 раз. Удваивание кол-ва экспериментов также увеличивает время в два раза.

# %% [markdown]
# ### 2.4 Графики зависимости

# %% [markdown]
# #### __1 Вариант:__
# ![image.png](data:image/png;base64,...)
# #### __2 Вариант:__
# ![image.png](data:image/png;base64,...)
# #### __3 Вариант:__
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Реализация

# %% [markdown]
# ### 3.1 Код на языке Python

# %%
https://github.com/Likstor/DSU_experiment

# %% [markdown]
# ### 3.2 Примеры работы алгоритма

# %%
# Пример 1: #

# Выберите тип СНМ (qf или qu): qf
# Введите размер решетки: 100
# Введите количество испытаний: 2

# 100%|██████████| 2/2 [00:13<00:00,  6.84s/it]

# mean                    = 0.5922499999999999
# stddev                  = 0.004030508652763269
# 95% confidence interval = 0.586664, 0.5978359999999999

# Пример 2: #

# Выберите тип СНМ (qf или qu): qu
# Введите размер решетки: 100
# Введите количество испытаний: 3
# 100%|██████████| 3/3 [00:29<00:00,  9.71s/it]

# mean                    = 0.6100333333333334
# stddev                  = 0.01977734394031039
# 95% confidence interval = 0.5876531618316572, 0.6324135048350097

# Пример 3: #

# Выберите тип СНМ (qf или qu): qf
# Введите размер решетки: 50
# Введите количество испытаний: 2
# 100%|██████████| 2/2 [00:00<00:00,  2.83it/s]

# mean                    = 0.5402
# stddev                  = 0.0019798989873223505
# 95% confidence interval = 0.537456, 0.542944

# Пример 4: #

# Выберите тип СНМ (qf или qu): qu
# Введите размер решетки: 50
# Введите количество испытаний: 2
# 100%|██████████| 2/2 [00:00<00:00,  2.19it/s]

# mean                    = 0.615
# stddev                  = 0.008768124086713167
# 95% confidence interval = 0.602848, 0.6271519999999999

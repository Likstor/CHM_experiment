# %% [markdown]
# # Домашнее задание №2 «Проектное задание»
# *Выполнили: Иванов Иван Иванович, Петров Петр Петрович*

# %% [markdown]
# ## 1. Название задания

# %% [markdown]
# *перепишите сюда название домашнего задания*
#
# *все комментарии из этого и последующих разделов удалите*
#
# **обязательно укажите автора каждого раздела ноутбука**

# %% [markdown]
# ## 2. Алгоритм

# %% [markdown]
# ### 2.1 Псевдокод алгоритма

# %% [markdown]
# *вставьте сюда псевдокод вашего алгоритма в нотации, используемой на лекциях (пронумеруйте все строки, выделяйте ключевые слова, делайте отступы и т.д.)*

# %% [markdown]
# ### 2.2 Описание работы алгоритма

# %% [markdown]
# *опишите логику работы вашего алгоритма, ссылаясь на номера строк псевдокода*

# %% [markdown]
# ### 2.3 Оценка времени работы

# %% [markdown]
# *оцените время работы вашего алгоритма и обоснуйте свою оценку*

# %% [markdown]
# ## 3. Реализация

# %% [markdown]
# ### 3.1 Код на языке Python

# %%
# Вставьте сюда ваш код с комментариями

# %% [markdown]
# ### 3.2 Примеры работы алгоритма

# %%
# Вызовите несколько раз ваш алгоритм на различных примерах входных данных
